# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 759

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | kavieng
# Processing Record 5 of Set 1 | taoudenni
# Processing Record 6 of Set 1 | mamedkala
# Processing Record 7 of Set 1 | killybegs
# Processing Record 8 of Set 1 | pingliang
# Processing Record 9 of Set 1 | tambacounda
# Processing Record 10 of Set 1 | tessalit
# Processing Record 11 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 1 | muravlenko
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | kropotkin
# Processing Record 16 of Set 1 | san quintin
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | luderitz
# Processing Record 20 of Set 1 | kijang
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | mangrol
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | port blair
# Processing Record 25 of Set 1 | tuy hoa
# Processing Record 26 of Set 1 | iskateley
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | gisborne
# Processing Record 31 of Set 1 | huilong
# Processing Record 32 of Set 1 | tazovskiy
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | khipro
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | cherskiy
# Processing Record 38 of Set 1 | bowen
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | jos
# Processing Record 41 of Set 1 | oxapampa
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | alghero
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | naryan-mar
# Processing Record 47 of Set 1 | port macquarie
# Processing Record 48 of Set 1 | kaeo
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | port moresby
# Processing Record 1 of Set 2 | ust-koksa
# Processing Record 2 of Set 2 | trincomalee
# Processing Record 3 of Set 2 | tura
# Processing Record 4 of Set 2 | bilma
# Processing Record 5 of Set 2 | geraldton
# Processing Record 6 of Set 2 | voyinka
# Processing Record 7 of Set 2 | langsa
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | airai
# Processing Record 10 of Set 2 | datong
# Processing Record 11 of Set 2 | severnyy
# Processing Record 12 of Set 2 | kundla
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | kusk
# City not found. Skipping...
# Processing Record 15 of Set 2 | hambantota
# Processing Record 16 of Set 2 | plouzane
# Processing Record 17 of Set 2 | iqaluit
# Processing Record 18 of Set 2 | jaen
# Processing Record 19 of Set 2 | pokhara
# Processing Record 20 of Set 2 | eureka
# Processing Record 21 of Set 2 | eyl
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | ponta do sol
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | souillac
# Processing Record 28 of Set 2 | rawson
# Processing Record 29 of Set 2 | bulalacao
# Processing Record 30 of Set 2 | korla
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | vestbygda
# City not found. Skipping...
# Processing Record 33 of Set 2 | kuntaur
# Processing Record 34 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | mount gambier
# Processing Record 39 of Set 2 | avera
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | vanavara
# Processing Record 42 of Set 2 | isangel
# Processing Record 43 of Set 2 | wufeng
# Processing Record 44 of Set 2 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 45 of Set 2 | pangnirtung
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 2 | sangar
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | bilibino
# Processing Record 1 of Set 3 | beyneu
# Processing Record 2 of Set 3 | marrakesh
# Processing Record 3 of Set 3 | tiksi
# Processing Record 4 of Set 3 | demidov
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | tautira
# Processing Record 7 of Set 3 | bambous virieux
# Processing Record 8 of Set 3 | chebsara
# Processing Record 9 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 3 | baboua
# City not found. Skipping...
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 3 | marica
# Processing Record 14 of Set 3 | nanortalik
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 3 | guerrero negro
# Processing Record 19 of Set 3 | bernalillo
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | ribeira grande
# Processing Record 22 of Set 3 | punta arenas
# Processing Record 23 of Set 3 | vilyuysk
# Processing Record 24 of Set 3 | peniche
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | araguaina
# Processing Record 27 of Set 3 | severo-kurilsk
# Processing Record 28 of Set 3 | busselton
# Processing Record 29 of Set 3 | kanuma
# Processing Record 30 of Set 3 | kapit
# Processing Record 31 of Set 3 | okhotsk
# Processing Record 32 of Set 3 | tirano
# Processing Record 33 of Set 3 | leshukonskoye
# Processing Record 34 of Set 3 | lom sak
# Processing Record 35 of Set 3 | damara
# Processing Record 36 of Set 3 | biak
# Processing Record 37 of Set 3 | nyrob
# Processing Record 38 of Set 3 | monte alegre
# Processing Record 39 of Set 3 | kaitangata
# Processing Record 40 of Set 3 | roald
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | bereda
# Processing Record 43 of Set 3 | praia da vitoria
# Processing Record 44 of Set 3 | donskoye
# Processing Record 45 of Set 3 | saint marys
# Processing Record 46 of Set 3 | sorland
# Processing Record 47 of Set 3 | yokadouma
# Processing Record 48 of Set 3 | beringovskiy
# Processing Record 49 of Set 3 | vangaindrano
# Processing Record 50 of Set 3 | mataura
# Processing Record 1 of Set 4 | egvekinot
# Processing Record 2 of Set 4 | hefei
# Processing Record 3 of Set 4 | dikson
# Processing Record 4 of Set 4 | tabulbah
# City not found. Skipping...
# Processing Record 5 of Set 4 | saskylakh
# Processing Record 6 of Set 4 | mount isa
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | jamestown
# Processing Record 9 of Set 4 | changde
# Processing Record 10 of Set 4 | bahia blanca
# Processing Record 11 of Set 4 | ryotsu
# Processing Record 12 of Set 4 | fantanele
# Processing Record 13 of Set 4 | port lincoln
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 16 of Set 4 | dingle
# Processing Record 17 of Set 4 | imbituba
# Processing Record 18 of Set 4 | erdaojiang
# Processing Record 19 of Set 4 | kalinovskaya
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | wakkanai
# Processing Record 22 of Set 4 | carnarvon
# Processing Record 23 of Set 4 | fortuna
# Processing Record 24 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 4 | los llanos de aridane
# Processing Record 26 of Set 4 | prieska
# Processing Record 27 of Set 4 | morondava
# Processing Record 28 of Set 4 | aranos
# Processing Record 29 of Set 4 | goycay
# City not found. Skipping...
# Processing Record 30 of Set 4 | loviisa
# Processing Record 31 of Set 4 | omegna
# Processing Record 32 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 4 | chuy
# Processing Record 34 of Set 4 | touros
# Processing Record 35 of Set 4 | doha
# Processing Record 36 of Set 4 | presidente olegario
# Processing Record 37 of Set 4 | palmas
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | kalmunai
# Processing Record 40 of Set 4 | namibe
# Processing Record 41 of Set 4 | isla vista
# Processing Record 42 of Set 4 | bethel
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 4 | port augusta
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | clyde river
# Processing Record 48 of Set 4 | harper
# Processing Record 49 of Set 4 | ballitoville
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | malartic
# Processing Record 2 of Set 5 | corcoran
# Processing Record 3 of Set 5 | sokolo
# Processing Record 4 of Set 5 | pisco
# Processing Record 5 of Set 5 | alta floresta
# Processing Record 6 of Set 5 | nicolas bravo
# Processing Record 7 of Set 5 | sao joao da barra
# Processing Record 8 of Set 5 | mantua
# Processing Record 9 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 10 of Set 5 | porbandar
# Processing Record 11 of Set 5 | gat
# Processing Record 12 of Set 5 | alofi
# Processing Record 13 of Set 5 | atherton
# Processing Record 14 of Set 5 | saint anthony
# Processing Record 15 of Set 5 | la ronge
# Processing Record 16 of Set 5 | talaya
# Processing Record 17 of Set 5 | mabaruma
# Processing Record 18 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | newport
# Processing Record 20 of Set 5 | kassala
# Processing Record 21 of Set 5 | najran
# Processing Record 22 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 5 | aljezur
# Processing Record 24 of Set 5 | shwebo
# Processing Record 25 of Set 5 | kahului
# Processing Record 26 of Set 5 | duenas
# Processing Record 27 of Set 5 | port-gentil
# Processing Record 28 of Set 5 | simplicio mendes
# Processing Record 29 of Set 5 | mosetse
# Processing Record 30 of Set 5 | xuanhua
# Processing Record 31 of Set 5 | raga
# Processing Record 32 of Set 5 | ligayan
# Processing Record 33 of Set 5 | haimen
# Processing Record 34 of Set 5 | chenghai
# Processing Record 35 of Set 5 | fort nelson
# Processing Record 36 of Set 5 | twentynine palms
# Processing Record 37 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 5 | tasiilaq
# Processing Record 39 of Set 5 | kultuk
# Processing Record 40 of Set 5 | coihaique
# Processing Record 41 of Set 5 | saint george
# Processing Record 42 of Set 5 | rocha
# Processing Record 43 of Set 5 | dawson creek
# Processing Record 44 of Set 5 | sitka
# Processing Record 45 of Set 5 | mormugao
# Processing Record 46 of Set 5 | san patricio
# Processing Record 47 of Set 5 | saint-philippe
# Processing Record 48 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 5 | santa cruz verapaz
# Processing Record 50 of Set 5 | college
# Processing Record 1 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 2 of Set 6 | husavik
# Processing Record 3 of Set 6 | cabo san lucas
# Processing Record 4 of Set 6 | corning
# Processing Record 5 of Set 6 | miri
# Processing Record 6 of Set 6 | ahipara
# Processing Record 7 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 6 | san ciro de acosta
# Processing Record 9 of Set 6 | thaton
# Processing Record 10 of Set 6 | petauke
# Processing Record 11 of Set 6 | palmer
# Processing Record 12 of Set 6 | kununurra
# Processing Record 13 of Set 6 | oranjemund
# Processing Record 14 of Set 6 | richards bay
# Processing Record 15 of Set 6 | buala
# Processing Record 16 of Set 6 | mackay
# Processing Record 17 of Set 6 | saint-augustin
# Processing Record 18 of Set 6 | eydhafushi
# Processing Record 19 of Set 6 | iwanai
# Processing Record 20 of Set 6 | yantarnyy
# Processing Record 21 of Set 6 | caluquembe
# Processing Record 22 of Set 6 | komsomolskiy
# Processing Record 23 of Set 6 | aguimes
# Processing Record 24 of Set 6 | andarab
# City not found. Skipping...
# Processing Record 25 of Set 6 | yerbogachen
# Processing Record 26 of Set 6 | roquetas de mar
# Processing Record 27 of Set 6 | keta
# Processing Record 28 of Set 6 | payo
# Processing Record 29 of Set 6 | hami
# Processing Record 30 of Set 6 | shimoda
# Processing Record 31 of Set 6 | kruisfontein
# Processing Record 32 of Set 6 | arcos
# Processing Record 33 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 6 | auki
# Processing Record 35 of Set 6 | viedma
# Processing Record 36 of Set 6 | maragogi
# Processing Record 37 of Set 6 | asau
# Processing Record 38 of Set 6 | safaqis
# City not found. Skipping...
# Processing Record 39 of Set 6 | yulara
# Processing Record 40 of Set 6 | kpalime
# Processing Record 41 of Set 6 | lipin bor
# Processing Record 42 of Set 6 | henties bay
# Processing Record 43 of Set 6 | saint-joseph
# Processing Record 44 of Set 6 | paamiut
# Processing Record 45 of Set 6 | bestobe
# Processing Record 46 of Set 6 | miamisburg
# Processing Record 47 of Set 6 | conde
# Processing Record 48 of Set 6 | baykit
# Processing Record 49 of Set 6 | namatanai
# Processing Record 50 of Set 6 | castelldefels
# Processing Record 1 of Set 7 | komsomolskoye
# Processing Record 2 of Set 7 | vagur
# Processing Record 3 of Set 7 | sochaczew
# Processing Record 4 of Set 7 | carndonagh
# Processing Record 5 of Set 7 | bereznehuvate
# Processing Record 6 of Set 7 | tevaitoa
# Processing Record 7 of Set 7 | virginia beach
# Processing Record 8 of Set 7 | hofn
# Processing Record 9 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 7 | talcahuano
# Processing Record 11 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 7 | kungurtug
# Processing Record 13 of Set 7 | iquique
# Processing Record 14 of Set 7 | rialma
# Processing Record 15 of Set 7 | alyangula
# Processing Record 16 of Set 7 | aksarka
# Processing Record 17 of Set 7 | srandakan
# Processing Record 18 of Set 7 | barsovo
# Processing Record 19 of Set 7 | we
# City not found. Skipping...
# Processing Record 20 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 21 of Set 7 | arraial do cabo
# Processing Record 22 of Set 7 | nyurba
# Processing Record 23 of Set 7 | saravena
# Processing Record 24 of Set 7 | fushun
# Processing Record 25 of Set 7 | hamilton
# Processing Record 26 of Set 7 | general roca
# Processing Record 27 of Set 7 | koulamoutou
# Processing Record 28 of Set 7 | umm lajj
# Processing Record 29 of Set 7 | nikolskoye
# Processing Record 30 of Set 7 | marondera
# Processing Record 31 of Set 7 | goma
# Processing Record 32 of Set 7 | villeneuve-sur-lot
# Processing Record 33 of Set 7 | mahajanga
# Processing Record 34 of Set 7 | codrington
# Processing Record 35 of Set 7 | vila velha
# Processing Record 36 of Set 7 | saldanha
# Processing Record 37 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 38 of Set 7 | axim
# Processing Record 39 of Set 7 | upernavik
# Processing Record 40 of Set 7 | erenhot
# Processing Record 41 of Set 7 | xuchang
# Processing Record 42 of Set 7 | salalah
# Processing Record 43 of Set 7 | calvinia
# Processing Record 44 of Set 7 | siniscola
# Processing Record 45 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 7 | puerto escondido
# Processing Record 47 of Set 7 | tiarei
# Processing Record 48 of Set 7 | tlahualilo
# City not found. Skipping...
# Processing Record 49 of Set 7 | monrovia
# Processing Record 50 of Set 7 | brentwood
# Processing Record 1 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 8 | kaseda
# Processing Record 3 of Set 8 | abbeville
# Processing Record 4 of Set 8 | yaan
# Processing Record 5 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 8 | ayna
# Processing Record 7 of Set 8 | sao filipe
# Processing Record 8 of Set 8 | sinnamary
# Processing Record 9 of Set 8 | karratha
# Processing Record 10 of Set 8 | aanekoski
# Processing Record 11 of Set 8 | altay
# Processing Record 12 of Set 8 | luganville
# Processing Record 13 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 8 | constitucion
# Processing Record 15 of Set 8 | carbonia
# Processing Record 16 of Set 8 | leningradskiy
# Processing Record 17 of Set 8 | christchurch
# Processing Record 18 of Set 8 | kemijarvi
# Processing Record 19 of Set 8 | rio gallegos
# Processing Record 20 of Set 8 | key west
# Processing Record 21 of Set 8 | panguna
# Processing Record 22 of Set 8 | ulfborg
# Processing Record 23 of Set 8 | yuli
# Processing Record 24 of Set 8 | vitim
# Processing Record 25 of Set 8 | westerland
# Processing Record 26 of Set 8 | iralaya
# Processing Record 27 of Set 8 | provideniya
# Processing Record 28 of Set 8 | quetzaltenango
# Processing Record 29 of Set 8 | acarau
# Processing Record 30 of Set 8 | pevek
# Processing Record 31 of Set 8 | kedrovyy
# Processing Record 32 of Set 8 | ramgarh
# Processing Record 33 of Set 8 | bubaque
# Processing Record 34 of Set 8 | hualmay
# Processing Record 35 of Set 8 | laguna
# Processing Record 36 of Set 8 | coro
# Processing Record 37 of Set 8 | kamloops
# Processing Record 38 of Set 8 | hearst
# Processing Record 39 of Set 8 | xihe
# Processing Record 40 of Set 8 | san cristobal
# Processing Record 41 of Set 8 | divnomorskoye
# Processing Record 42 of Set 8 | dicabisagan
# Processing Record 43 of Set 8 | derzhavinsk
# Processing Record 44 of Set 8 | inhambane
# Processing Record 45 of Set 8 | srednekolymsk
# Processing Record 46 of Set 8 | irbil
# Processing Record 47 of Set 8 | klyuchi
# Processing Record 48 of Set 8 | cotonou
# Processing Record 49 of Set 8 | maldonado
# Processing Record 50 of Set 8 | ust-kuyga
# Processing Record 1 of Set 9 | betma
# Processing Record 2 of Set 9 | narsaq
# Processing Record 3 of Set 9 | atasu
# Processing Record 4 of Set 9 | kermanshah
# Processing Record 5 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 9 | vanimo
# Processing Record 7 of Set 9 | presidencia roque saenz pena
# Processing Record 8 of Set 9 | thinadhoo
# Processing Record 9 of Set 9 | yuanping
# Processing Record 10 of Set 9 | vibo valentia
# Processing Record 11 of Set 9 | vostok
# Processing Record 12 of Set 9 | pozo colorado
# Processing Record 13 of Set 9 | lac du bonnet
# Processing Record 14 of Set 9 | forbes
# Processing Record 15 of Set 9 | havre-saint-pierre
# Processing Record 16 of Set 9 | lompoc
# Processing Record 17 of Set 9 | kuytun
# Processing Record 18 of Set 9 | barhi
# Processing Record 19 of Set 9 | coihueco
# Processing Record 20 of Set 9 | kaduqli
# Processing Record 21 of Set 9 | miquelon
# Processing Record 22 of Set 9 | boromo
# Processing Record 23 of Set 9 | mayumba
# Processing Record 24 of Set 9 | solnechnyy
# Processing Record 25 of Set 9 | teteven
# Processing Record 26 of Set 9 | matara
# Processing Record 27 of Set 9 | mhlume
# Processing Record 28 of Set 9 | sandakan
# Processing Record 29 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 9 | belyy yar
# Processing Record 31 of Set 9 | margate
# Processing Record 32 of Set 9 | conakry
# Processing Record 33 of Set 9 | vaitape
# Processing Record 34 of Set 9 | deh rawud
# City not found. Skipping...
# Processing Record 35 of Set 9 | norman wells
# Processing Record 36 of Set 9 | portland
# Processing Record 37 of Set 9 | moree
# Processing Record 38 of Set 9 | broken hill
# Processing Record 39 of Set 9 | kaset sombun
# Processing Record 40 of Set 9 | mikuni
# Processing Record 41 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 9 | esso
# Processing Record 43 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 9 | nyimba
# Processing Record 45 of Set 9 | pacanga
# Processing Record 46 of Set 9 | bandarbeyla
# Processing Record 47 of Set 9 | dorado
# Processing Record 48 of Set 9 | nouadhibou
# Processing Record 49 of Set 9 | itupiranga
# Processing Record 50 of Set 9 | kieta
# Processing Record 1 of Set 10 | alice springs
# Processing Record 2 of Set 10 | shaunavon
# Processing Record 3 of Set 10 | zhigansk
# Processing Record 4 of Set 10 | uige
# Processing Record 5 of Set 10 | aklavik
# Processing Record 6 of Set 10 | ostrovnoy
# Processing Record 7 of Set 10 | aleksandrovsk-sakhalinskiy
# Processing Record 8 of Set 10 | moron
# Processing Record 9 of Set 10 | ordu
# Processing Record 10 of Set 10 | adrar
# Processing Record 11 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 12 of Set 10 | hasaki
# Processing Record 13 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 14 of Set 10 | stamsund
# City not found. Skipping...
# Processing Record 15 of Set 10 | gao
# Processing Record 16 of Set 10 | porto novo
# Processing Record 17 of Set 10 | traiguen
# Processing Record 18 of Set 10 | belaya gora
# Processing Record 19 of Set 10 | maniitsoq
# Processing Record 20 of Set 10 | penzance
# Processing Record 21 of Set 10 | vestmanna
# Processing Record 22 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 23 of Set 10 | pentecoste
# Processing Record 24 of Set 10 | toguchin
# Processing Record 25 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 26 of Set 10 | dukat
# Processing Record 27 of Set 10 | kupang
# Processing Record 28 of Set 10 | usinsk
# Processing Record 29 of Set 10 | half moon bay
# Processing Record 30 of Set 10 | marsh harbour
# Processing Record 31 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 10 | praya
# Processing Record 33 of Set 10 | boa vista
# Processing Record 34 of Set 10 | kitui
# Processing Record 35 of Set 10 | evensk
# Processing Record 36 of Set 10 | la poza
# Processing Record 37 of Set 10 | benguela
# Processing Record 38 of Set 10 | dana point
# Processing Record 39 of Set 10 | saurimo
# Processing Record 40 of Set 10 | cururupu
# Processing Record 41 of Set 10 | nome
# Processing Record 42 of Set 10 | kitimat
# Processing Record 43 of Set 10 | minsk
# Processing Record 44 of Set 10 | piste
# Processing Record 45 of Set 10 | kotlas
# Processing Record 46 of Set 10 | abu samrah
# Processing Record 47 of Set 10 | nago
# Processing Record 48 of Set 10 | borlange
# City not found. Skipping...
# Processing Record 49 of Set 10 | sangmelima
# Processing Record 50 of Set 10 | longyearbyen
# Processing Record 1 of Set 11 | nha trang
# Processing Record 2 of Set 11 | farafangana
# Processing Record 3 of Set 11 | rio grande
# Processing Record 4 of Set 11 | kampong cham
# Processing Record 5 of Set 11 | jimma
# Processing Record 6 of Set 11 | dengzhou
# Processing Record 7 of Set 11 | bulolo
# Processing Record 8 of Set 11 | mana
# Processing Record 9 of Set 11 | lengshuitan
# Processing Record 10 of Set 11 | akwatia
# Processing Record 11 of Set 11 | minbu
# Processing Record 12 of Set 11 | isparta
# Processing Record 13 of Set 11 | hirara
# Processing Record 14 of Set 11 | sarakhs
# Processing Record 15 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 16 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 11 | mehamn
# Processing Record 18 of Set 11 | huangpi
# Processing Record 19 of Set 11 | lamu
# Processing Record 20 of Set 11 | ganzhou
# Processing Record 21 of Set 11 | nelson bay
# Processing Record 22 of Set 11 | mount pleasant
# Processing Record 23 of Set 11 | taber
# Processing Record 24 of Set 11 | ayagoz
# Processing Record 25 of Set 11 | borger
# Processing Record 26 of Set 11 | galesong
# Processing Record 27 of Set 11 | kysyl-syr
# Processing Record 28 of Set 11 | sisimiut
# Processing Record 29 of Set 11 | ilkal
# Processing Record 30 of Set 11 | mayo
# Processing Record 31 of Set 11 | manadhoo
# Processing Record 32 of Set 11 | jijiga
# Processing Record 33 of Set 11 | ati
# Processing Record 34 of Set 11 | salinas
# Processing Record 35 of Set 11 | vao
# Processing Record 36 of Set 11 | great yarmouth
# Processing Record 37 of Set 11 | tateyama
# Processing Record 38 of Set 11 | honiara
# Processing Record 39 of Set 11 | camacha
# Processing Record 40 of Set 11 | uniao da victoria
# City not found. Skipping...
# Processing Record 41 of Set 11 | zabid
# Processing Record 42 of Set 11 | mao
# Processing Record 43 of Set 11 | menongue
# Processing Record 44 of Set 11 | lazaro cardenas
# Processing Record 45 of Set 11 | providencia
# Processing Record 46 of Set 11 | klaksvik
# Processing Record 47 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 48 of Set 11 | port hedland
# Processing Record 49 of Set 11 | faanui
# Processing Record 50 of Set 11 | chapais
# Processing Record 1 of Set 12 | la malbaie
# Processing Record 2 of Set 12 | leh
# Processing Record 3 of Set 12 | jodhpur
# Processing Record 4 of Set 12 | alekseyevsk
# Processing Record 5 of Set 12 | tanete
# Processing Record 6 of Set 12 | sretensk
# Processing Record 7 of Set 12 | dhandhuka
# Processing Record 8 of Set 12 | tapes
# Processing Record 9 of Set 12 | ailigandi
# Processing Record 10 of Set 12 | burns lake
# Processing Record 11 of Set 12 | santos dumont
# Processing Record 12 of Set 12 | krasnoselkup
# Processing Record 13 of Set 12 | dayong
# Processing Record 14 of Set 12 | khandyga
# Processing Record 15 of Set 12 | puerto del rosario
# Processing Record 16 of Set 12 | mariakani
# Processing Record 17 of Set 12 | toungoo
# City not found. Skipping...
# Processing Record 18 of Set 12 | umba
# Processing Record 19 of Set 12 | seymchan
# Processing Record 20 of Set 12 | riviere-au-renard
# Processing Record 21 of Set 12 | samarai
# Processing Record 22 of Set 12 | zhizdra
# Processing Record 23 of Set 12 | ca mau
# Processing Record 24 of Set 12 | bocas del toro
# Processing Record 25 of Set 12 | gwanda
# Processing Record 26 of Set 12 | saint-pierre
# Processing Record 27 of Set 12 | mushie
# Processing Record 28 of Set 12 | atar
# Processing Record 29 of Set 12 | gornorechenskiy
# Processing Record 30 of Set 12 | nurota
# Processing Record 31 of Set 12 | trairi
# Processing Record 32 of Set 12 | antofagasta
# Processing Record 33 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 12 | tomball
# Processing Record 35 of Set 12 | grand forks
# Processing Record 36 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 37 of Set 12 | sainte-maxime
# Processing Record 38 of Set 12 | prince rupert
# Processing Record 39 of Set 12 | northam
# Processing Record 40 of Set 12 | matata
# Processing Record 41 of Set 12 | raipur
# Processing Record 42 of Set 12 | pitimbu
# Processing Record 43 of Set 12 | puerto berrio
# Processing Record 44 of Set 12 | binga
# Processing Record 45 of Set 12 | olga
# Processing Record 46 of Set 12 | chicama
# Processing Record 47 of Set 12 | whitehorse
# Processing Record 48 of Set 12 | yumen
# Processing Record 49 of Set 12 | gushikawa
# Processing Record 50 of Set 12 | berbera
# Processing Record 1 of Set 13 | sabang
# Processing Record 2 of Set 13 | yakeshi
# Processing Record 3 of Set 13 | george town
# Processing Record 4 of Set 13 | arlit
# Processing Record 5 of Set 13 | lorengau
# Processing Record 6 of Set 13 | vardo
# Processing Record 7 of Set 13 | myitkyina
# Processing Record 8 of Set 13 | arazede
# Processing Record 9 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 13 | weston
# Processing Record 11 of Set 13 | candolim
# Processing Record 12 of Set 13 | alenquer
# Processing Record 13 of Set 13 | hay river
# Processing Record 14 of Set 13 | timra
# Processing Record 15 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 13 | moranbah
# Processing Record 17 of Set 13 | neiafu
# Processing Record 18 of Set 13 | telc
# Processing Record 19 of Set 13 | bac lieu
# Processing Record 20 of Set 13 | craig
# Processing Record 21 of Set 13 | tarapur
# Processing Record 22 of Set 13 | ketchikan
# Processing Record 23 of Set 13 | sarh
# Processing Record 24 of Set 13 | sampit
# Processing Record 25 of Set 13 | goderich
# Processing Record 26 of Set 13 | vila franca do campo
# Processing Record 27 of Set 13 | baijiantan
# Processing Record 28 of Set 13 | port hardy
# Processing Record 29 of Set 13 | zhangzhou
# Processing Record 30 of Set 13 | sobolevo
# Processing Record 31 of Set 13 | saint-francois
# Processing Record 32 of Set 13 | ojinaga
# Processing Record 33 of Set 13 | calatayud
# Processing Record 34 of Set 13 | ambilobe
# Processing Record 35 of Set 13 | egra
# Processing Record 36 of Set 13 | bibiani
# Processing Record 37 of Set 13 | comodoro rivadavia
# Processing Record 38 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 39 of Set 13 | kisangani
# Processing Record 40 of Set 13 | oban
# Processing Record 41 of Set 13 | mabay
# Processing Record 42 of Set 13 | dakar
# Processing Record 43 of Set 13 | sa kaeo
# Processing Record 44 of Set 13 | jalu
# Processing Record 45 of Set 13 | zhanjiang
# Processing Record 46 of Set 13 | san lorenzo
# Processing Record 47 of Set 13 | yeppoon
# Processing Record 48 of Set 13 | bagdarin
# Processing Record 49 of Set 13 | khorinsk
# Processing Record 50 of Set 13 | soskovo
# Processing Record 1 of Set 14 | teeli
# Processing Record 2 of Set 14 | yarmouth
# Processing Record 3 of Set 14 | uray
# Processing Record 4 of Set 14 | templin
# Processing Record 5 of Set 14 | lubben
# Processing Record 6 of Set 14 | wageningen
# Processing Record 7 of Set 14 | quartucciu
# Processing Record 8 of Set 14 | buraydah
# Processing Record 9 of Set 14 | bangkalan
# Processing Record 10 of Set 14 | le portel
# Processing Record 11 of Set 14 | cairns
# Processing Record 12 of Set 14 | ucluelet
# Processing Record 13 of Set 14 | north bend
# Processing Record 14 of Set 14 | sri aman
# Processing Record 15 of Set 14 | mosquera
# Processing Record 16 of Set 14 | tobermory
# Processing Record 17 of Set 14 | kavaratti
# Processing Record 18 of Set 14 | aginskoye
# Processing Record 19 of Set 14 | zgierz
# Processing Record 20 of Set 14 | turkan
# Processing Record 21 of Set 14 | pemangkat
# Processing Record 22 of Set 14 | aktash
# Processing Record 23 of Set 14 | tsabong
# Processing Record 24 of Set 14 | lasa
# Processing Record 25 of Set 14 | lewisporte
# Processing Record 26 of Set 14 | dunedin
# Processing Record 27 of Set 14 | meulaboh
# Processing Record 28 of Set 14 | edd
# Processing Record 29 of Set 14 | manga
# Processing Record 30 of Set 14 | provost
# Processing Record 31 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 32 of Set 14 | pitea
# Processing Record 33 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 14 | kozhva
# Processing Record 35 of Set 14 | shingu
# Processing Record 36 of Set 14 | lima
# Processing Record 37 of Set 14 | tres barras
# Processing Record 38 of Set 14 | cayenne
# Processing Record 39 of Set 14 | fuzhou
# Processing Record 40 of Set 14 | nuuk
# Processing Record 41 of Set 14 | purranque
# Processing Record 42 of Set 14 | trelew
# Processing Record 43 of Set 14 | tual
# Processing Record 44 of Set 14 | quatre cocos
# Processing Record 45 of Set 14 | bozeman
# Processing Record 46 of Set 14 | florianopolis
# Processing Record 47 of Set 14 | morro bay
# Processing Record 48 of Set 14 | mezhdurechenskiy
# Processing Record 49 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 50 of Set 14 | zdvinsk
# Processing Record 1 of Set 15 | naze
# Processing Record 2 of Set 15 | montalvo
# Processing Record 3 of Set 15 | emerald
# Processing Record 4 of Set 15 | lavrentiya
# Processing Record 5 of Set 15 | eregli
# Processing Record 6 of Set 15 | padang
# Processing Record 7 of Set 15 | liverpool
# Processing Record 8 of Set 15 | ayr
# Processing Record 9 of Set 15 | dondo
# Processing Record 10 of Set 15 | altagracia de orituco
# Processing Record 11 of Set 15 | saint-georges
# Processing Record 12 of Set 15 | atambua
# Processing Record 13 of Set 15 | ranong
# Processing Record 14 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 15 | bima
# Processing Record 16 of Set 15 | tiznit
# Processing Record 17 of Set 15 | oskarshamn
# Processing Record 18 of Set 15 | kampong thum
# Processing Record 19 of Set 15 | omsukchan
# Processing Record 20 of Set 15 | asyut
# Processing Record 21 of Set 15 | biltine
# Processing Record 22 of Set 15 | campo formoso
# Processing Record 23 of Set 15 | ola
# Processing Record 24 of Set 15 | layou
# Processing Record 25 of Set 15 | kingman
# Processing Record 26 of Set 15 | ponta delgada
# Processing Record 27 of Set 15 | dhankuta
# Processing Record 28 of Set 15 | rudnogorsk
# Processing Record 29 of Set 15 | puerto madryn
# Processing Record 30 of Set 15 | konya
# Processing Record 31 of Set 15 | salina
# Processing Record 32 of Set 15 | kristinehamn
# Processing Record 33 of Set 15 | pringsewu
# Processing Record 34 of Set 15 | praia
# Processing Record 35 of Set 15 | wajid
# Processing Record 36 of Set 15 | kargopol
# Processing Record 37 of Set 15 | kushiro
# Processing Record 38 of Set 15 | piterka
# Processing Record 39 of Set 15 | mobaye
# Processing Record 40 of Set 15 | talavera de la reina
# Processing Record 41 of Set 15 | olafsvik
# Processing Record 42 of Set 15 | garowe
# Processing Record 43 of Set 15 | wukari
# Processing Record 44 of Set 15 | sindor
# Processing Record 45 of Set 15 | freeport
# Processing Record 46 of Set 15 | westport
# Processing Record 47 of Set 15 | havelock
# Processing Record 48 of Set 15 | zakopane
# Processing Record 49 of Set 15 | kokopo
# Processing Record 50 of Set 15 | coquimbo
# Processing Record 1 of Set 16 | dickinson
# Processing Record 2 of Set 16 | nhamunda
# Processing Record 3 of Set 16 | krasnoyarskiy
# Processing Record 4 of Set 16 | lata
# Processing Record 5 of Set 16 | goundi
# Processing Record 6 of Set 16 | grindavik
# Processing Record 7 of Set 16 | bulanash
# Processing Record 8 of Set 16 | flinders
# Processing Record 9 of Set 16 | makakilo city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 717

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Alfred      ZA -33.5906   26.8910     73.58        33           2
# 1  East London      ZA -33.0153   27.9116     67.14        52           0
# 2      Rikitea      PF -23.1203 -134.9692     74.35        78         100
# 3      Kavieng      PG  -2.5744  150.7967     81.86        80          71
# 4    Taoudenni      ML  22.6783   -3.9836    112.41         9          70
# 5    Mamedkala      RU  42.1677   48.1199     83.46        49           0
# 6    Killybegs      IE  54.6333   -8.4500     69.51        76         100
# 7    Pingliang      CN  35.5392  106.6861     70.21        44          87
# 8  Tambacounda      SN  13.7539  -13.7586     95.05        49          75
# 9     Tessalit      ML  20.1986    1.0114     92.37        31          65
#
#    Wind Speed Current Description
# 0       13.98           clear sky
# 1        5.75           clear sky
# 2       17.54     overcast clouds
# 3       14.70          light rain
# 4       14.45       broken clouds
# 5        5.35           clear sky
# 6        6.60     overcast clouds
# 7        5.17     overcast clouds
# 8        9.22       broken clouds
# 9       16.60          light rain

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
